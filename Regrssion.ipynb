# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.datasets
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn import metrics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('Day3_House_Price_data.csv', encoding='latin1', on_bad_lines='skip')
df.head()
# Out:
#                                      <!DOCTYPE html>
# 0  <html lang="en" data-color-mode="auto" data-li...
# 1                                             <head>
# 2                             <meta charset="utf-8">
# 3    <link rel="dns-prefetch" href="https://githu...
# 4    <link rel="dns-prefetch" href="https://avata...

# %%
df.head()
# Out:
#                                      <!DOCTYPE html>
# 0  <html lang="en" data-color-mode="auto" data-li...
# 1                                             <head>
# 2                             <meta charset="utf-8">
# 3    <link rel="dns-prefetch" href="https://githu...
# 4    <link rel="dns-prefetch" href="https://avata...

# %%
df.sample(10)
# Out:
#                                        <!DOCTYPE html>
# 479    <svg aria-hidden="true" height="16" viewBox=...
# 725              <ul class="pagehead-actions flex-s...
# 833                                           Projects
# 708          <div class="flex-auto min-width-0 widt...
# 412            <div data-view-component="true">    ...
# 896                                             </svg>
# 16   <script crossorigin="anonymous" defer="defer" ...
# 802            <span id="insights-repo-tab-count" d...
# 361                                          </a></li>
# 100    <meta name="turbo-cache-control" content="no...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945 entries, 0 to 944
# Data columns (total 1 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   <!DOCTYPE html>  945 non-null    object
# dtypes: object(1)
# memory usage: 7.5+ KB

# %%
df.shape
# Out:
# (945, 1)

# %%
df.isnull().sum()
# Out:
# <!DOCTYPE html>    0
# dtype: int64

# %%
df.describe()
# Out:
#        <!DOCTYPE html>
# count              945
# unique             633
# top             </svg>
# freq                57

# %%
df.dropna(inplace=True)

# %%
print(df.columns)
# Out:
# Index(['<!DOCTYPE html>'], dtype='object')
